# %% [markdown]
# # Заливка данных SQLite3

# %% [markdown]
# #### Импорт библиотек

# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# ##### Проверка версии sqlite3 (должна быть больше, чем 3.25)

# %%
sqlite3.sqlite_version
# Out:
# '3.31.1'

# %% [markdown]
# #### Подключение к БД

# %%
con = sqlite3.connect('db')

# %% [markdown]
# #### Чтение данных

# %% [markdown]
# https://drive.google.com/file/d/1cUYNwlHjUZ6gZZMSFBdX0NCnvgRTprsQ/view?usp=sharing

# %%
! gdown --id 1cUYNwlHjUZ6gZZMSFBdX0NCnvgRTprsQ
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1cUYNwlHjUZ6gZZMSFBdX0NCnvgRTprsQ
# To: /content/german_credit_augmented.csv
# 100% 69.6k/69.6k [00:00<00:00, 76.3MB/s]

# %%
df = pd.read_csv('german_credit_augmented.csv')

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own             NaN              NaN           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich              NaN            936
# 3   35  female    3     own          little              NaN           1393
# 4   28    male    2     own          little              NaN            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %% [markdown]
# #### Форматирование даты из csv

# %%
df.contract_dt = pd.to_datetime(df.contract_dt, format='%Y-%m-%d %H:%M:%S')

# %%
df.dtypes
# Out:
# age                          int64
# sex                         object
# job                          int64
# housing                     object
# saving_accounts             object
# checking_account            object
# credit_amount                int64
# duration                     int64
# purpose                     object
# default                      int64
# contract_dt         datetime64[ns]
# client_id                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1000 non-null   int64
#  1   sex               1000 non-null   object
#  2   job               1000 non-null   int64
#  3   housing           1000 non-null   object
#  4   saving_accounts   817 non-null    object
#  5   checking_account  606 non-null    object
#  6   credit_amount     1000 non-null   int64
#  7   duration          1000 non-null   int64
#  8   purpose           1000 non-null   object
#  9   default           1000 non-null   int64
#  10  contract_dt       1000 non-null   datetime64[ns]
#  11  client_id         1000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# #### Загрузка данных в БД

# %%
df.to_sql('german_credit', con, index=False, if_exists='replace')
# Out:
# 1000

# %% [markdown]
# ##### Вспомогательная функция для чтения из БД

# %%
def select(sql):
    return pd.read_sql(sql, con)

# %% [markdown]
# ## Селект к таблице

# %%
sql = '''select t.* from german_credit t limit 5'''
# Запрос на чтение 5 строк

# %%
select(sql)
# Выполнение запроса
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
t = select(sql)

# %%
t
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %% [markdown]
# ### Подключение к гугл драйву

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
! ls '/content/drive/MyDrive/JN/Data/'
# Out:
# german_credit.db

# %% [markdown]
# #### Сохранение БД на гугл диске

# %%
con = sqlite3.connect('/content/drive/MyDrive/JN/Data/german_credit.db')

# %%
df.to_sql('german_credit', con, index=False, if_exists='replace')
# Out:
# 1000

# %% [markdown]
# # Заливка данных POSTGRESQL
# ### elephantsql.com + POSTGRESQL

# %% [markdown]
# Импортируем библиотеку

# %%
from sqlalchemy import create_engine
from sqlalchemy import text

# %% [markdown]
# 1. Создаём бесплатный сервер на elephantsql.com и копируем его URL
# 2. Создаём подключение (conn) для хранения там БД
# 3. Вписываем URL по образцу ('postgresql+psycopg2://kcycbfwg:dY5daXDri_sESFSTu8zZKFufD0GN2EBY@balarama.db.elephantsql.com/kcycbfwg')
#
# !!! ДО 2 СЛЕШЕЙ НИЧЕГО НЕ МЕНЯТЬ !!!
#
# postgres://bjmfiovz:zW0g7vZ8iC29JOykwyp-qvjWAa2_2WSc@balarama.db.elephantsql.com/bjmfiovz

# %% [markdown]
# #### Создаём подключение к elephantsql

# %%
engine = create_engine('postgresql+psycopg2://bjmfiovz:zW0g7vZ8iC29JOykwyp-qvjWAa2_2WSc@balarama.db.elephantsql.com/bjmfiovz')

# %%
conn = engine.connect()

# %% [markdown]
# postgres://kcycbfwg:dY5daXDri_sESFSTu8zZKFufD0GN2EBY@balarama.db.elephantsql.com/kcycbfwg

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own             NaN              NaN           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich              NaN            936
# 3   35  female    3     own          little              NaN           1393
# 4   28    male    2     own          little              NaN            776
#
#    duration    purpose  default         contract_dt  client_id
# 0         9   radio/TV        0 2008-06-29 18:52:00        210
# 1        12        car        0 2007-05-20 18:30:19        929
# 2         9  education        0 2008-04-27 08:23:07        200
# 3        11        car        0 2007-05-06 10:58:22         45
# 4        12   radio/TV        0 2007-07-21 13:22:14        358

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1000 non-null   int64
#  1   sex               1000 non-null   object
#  2   job               1000 non-null   int64
#  3   housing           1000 non-null   object
#  4   saving_accounts   817 non-null    object
#  5   checking_account  606 non-null    object
#  6   credit_amount     1000 non-null   int64
#  7   duration          1000 non-null   int64
#  8   purpose           1000 non-null   object
#  9   default           1000 non-null   int64
#  10  contract_dt       1000 non-null   datetime64[ns]
#  11  client_id         1000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 93.9+ KB

# %%
df.dtypes
# Out:
# age                          int64
# sex                         object
# job                          int64
# housing                     object
# saving_accounts             object
# checking_account            object
# credit_amount                int64
# duration                     int64
# purpose                     object
# default                      int64
# contract_dt         datetime64[ns]
# client_id                    int64
# dtype: object

# %% [markdown]
# #### Для ускорения загрузки БД в Postgresql ↓

# %%
import csv
from io import StringIO

from sqlalchemy import create_engine

def psql_insert_copy(table, conn, keys, data_iter):
    # gets a DBAPI connection that can provide a cursor
    dbapi_conn = conn.connection
    with dbapi_conn.cursor() as cur:
        s_buf = StringIO()
        writer = csv.writer(s_buf)
        writer.writerows(data_iter)
        s_buf.seek(0)

        columns = ', '.join('"{}"'.format(k) for k in keys)
        if table.schema:
            table_name = '{}.{}'.format(table.schema, table.name)
        else:
            table_name = table.name

        sql = 'COPY {} ({}) FROM STDIN WITH CSV'.format(
            table_name, columns)
        cur.copy_expert(sql=sql, file=s_buf)

# %% [markdown]
# Перед заливкой, загрузить только часть БД для проверки что всё ОК
#
# (В данном случае 10 случайных строк)

# %%
df.sample(50).to_sql('german_credit', engine,index=False,if_exists='replace',method=psql_insert_copy)

# %% [markdown]
# Если после проверки всё ок, то можно заливать

# %%
df.to_sql('german_credit', engine,index=False,if_exists='replace',method=psql_insert_copy)

# %% [markdown]
# ## Селект к таблице

# %%
def select_conn(query):
    return pd.read_sql(query, conn)

# %%
query = text('''select * from german_credit t''')

# %%
df1 = pd.read_sql_query(query, conn)

# %%
df1
# Out:
#     age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0    43    male    1     own          little             None           1533
# 1    38    male    1     own          little         moderate           1308
# 2    24    male    2     own        moderate         moderate           6560
# 3    30    male    3     own      quite rich             None           2333
# 4    28  female    2     own          little           little           3660
# 5    56    male    2     own          little             None            618
# 6    20  female    2     own            rich         moderate           1577
# 7    37  female    2     own          little         moderate           3612
# 8    31    male    2     own            None             rich           3148
# 9    28    male    2     own          little             None           9572
# 10   32    male    3    free          little             None           4686
# 11   66    male    1     own      quite rich         moderate            766
# 12   31    male    1     own          little         moderate           1928
# 13   63    male    2    free          little             rich            781
# 14   29    male    1     own            None         moderate           2333
# 15   21    male    1    rent          little           little           1987
# 16   35    male    2     own            None             None           1979
# 17   52    male    1     own          little           little           2315
# 18   46    male    3     own            None             None           7629
# 19   53    male    2    free          little           little           4870
# 20   31    male    2     own            None             None            929
# 21   27    male    2     own        moderate         moderate           4576
# 22   46    male    3     own            None             None           6842
# 23   47    male    2    free            None           little           8335
# 24   27    male    0     own            rich             rich            709
# 25   28    male    2     own          little           little           5371
# 26   28    male    2     own        moderate             rich           1323
# 27   51  female    2     own        moderate             None            682
# 28   25    male    2     own            None             None            999
# 29   50  female    1     own          little             rich           1047
# 30   25  female    2    rent            None           little           1371
# 31   34    male    1     own        moderate             None           1743
# 32   23    male    2     own            None         moderate           1444
# 33   34  female    3     own          little         moderate           2064
# 34   34    male    2    free            None             None           6527
# 35   30    male    3     own        moderate         moderate           1919
# 36   35  female    2    free          little           little           1198
# 37   24  female    2    rent            None           little           1275
# 38   57    male    2    free          little         moderate           2225
# 39   30    male    2     own          little         moderate           7966
# 40   45    male    2    free          little           little           7882
#     age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0    43    male    1     own          little             None           1533
# 1    38    male    1     own          little         moderate           1308
# 2    24    male    2     own        moderate         moderate           6560
# 3    30    male    3     own      quite rich             None           2333
# 4    28  female    2     own          little           little           3660
# 5    56    male    2     own          little             None            618
# 6    20  female    2     own            rich         moderate           1577
# 7    37  female    2     own          little         moderate           3612
# 8    31    male    2     own            None             rich           3148
# 9    28    male    2     own          little             None           9572
# 10   32    male    3    free          little             None           4686
# 11   66    male    1     own      quite rich         moderate            766
# 12   31    male    1     own          little         moderate           1928
# 13   63    male    2    free          little             rich            781
# 14   29    male    1     own            None         moderate           2333
# 15   21    male    1    rent          little           little           1987
# 16   35    male    2     own            None             None           1979
# 17   52    male    1     own          little           little           2315
# 18   46    male    3     own            None             None           7629
# 19   53    male    2    free          little           little           4870
# 20   31    male    2     own            None             None            929
# 21   27    male    2     own        moderate         moderate           4576
# 22   46    male    3     own            None             None           6842
# 23   47    male    2    free            None           little           8335
# 24   27    male    0     own            rich             rich            709
# 25   28    male    2     own          little           little           5371
# 26   28    male    2     own        moderate             rich           1323
# 27   51  female    2     own        moderate             None            682
# 28   25    male    2     own            None             None            999
# 29   50  female    1     own          little             rich           1047
# 30   25  female    2    rent            None           little           1371
# 31   34    male    1     own        moderate             None           1743
# 32   23    male    2     own            None         moderate           1444
# 33   34  female    3     own          little         moderate           2064
# 34   34    male    2    free            None             None           6527
# 35   30    male    3     own        moderate         moderate           1919
# 36   35  female    2    free          little           little           1198
# 37   24  female    2    rent            None           little           1275
# 38   57    male    2    free          little         moderate           2225
# 39   30    male    2     own          little         moderate           7966
# 40   45    male    2    free          little           little           7882
# 41   20    male    2     own        moderate           little            674
# 42   37    male    2     own            None             None           7409
# 43   48    male    2     own          little           little           1082
# 44   40    male    2     own            None             None           3077
# 45   38    male    2     own            None             None           3914
# 46   31    male    1     own          little           little           3108
# 47   22    male    2    free          little           little           3149
# 48   36    male    3    free          little           little           1940
# 49   47    male    2    free          little             None           5103
#
#     duration              purpose  default         contract_dt  client_id
# 0         18  furniture/equipment        1 2008-06-09 20:14:01        948
# 1         15              repairs        0 2007-08-12 03:28:06        641
# 2         48                  car        1 2007-07-11 18:49:28        706
# 3         30             radio/TV        0 2007-05-05 01:25:39         40
# 4         24             radio/TV        0 2008-01-26 12:52:50        630
# 5         12             radio/TV        0 2007-06-16 17:42:15         90
# 6         11  furniture/equipment        0 2007-07-03 09:23:24        167
# 7         18  furniture/equipment        0 2007-12-31 02:58:16        537
# 8         24             radio/TV        0 2008-04-06 05:34:53        718
# 9         36             business        1 2008-01-24 23:02:24        180
# 10        36                  car        0 2008-01-06 15:35:07        511
# 11        12             radio/TV        1 2007-10-26 17:35:49        137
# 12        18  furniture/equipment        1 2007-11-13 05:27:58        559
# 13        10                  car        0 2008-01-13 19:10:05        123
# 14        24  furniture/equipment        0 2008-03-20 05:38:14         50
# 15        24             radio/TV        1 2007-09-19 00:03:58        731
# 16        15             radio/TV        0 2008-03-03 11:32:53        625
# 17        10             radio/TV        0 2008-04-20 22:24:11         84
# 18        48             business        0 2007-09-04 10:12:48        294
# 19        24                  car        1 2007-10-05 03:47:21          4
# 20        24  furniture/equipment        0 2007-07-14 22:21:50        942
# 21        45                  car        0 2008-04-17 11:41:03        999
# 22        24                  car        0 2007-06-12 01:12:33        939
# 23        36                  car        1 2007-08-25 09:18:57        828
# 24         6                  car        0 2008-01-06 13:16:15        140
# 25        36  furniture/equipment        0 2007-11-09 06:36:14        148
# 26         6                  car        0 2007-12-04 01:06:54        499
# 27        12                  car        0 2007-09-27 05:59:47        147
# 28        24             radio/TV        0 2007-12-20 12:23:00        269
# 29         6            education        0 2007-09-10 19:04:25        664
# 30        24                  car        1 2007-11-09 03:10:57        775
# 31         6             business        0 2008-02-14 01:58:09        348
# 32        15             radio/TV        0 2007-07-30 07:29:04        632
# 33        24  furniture/equipment        1 2008-05-25 22:20:50        172
# 34        60                  car        0 2007-10-07 13:02:48        685
# 35        30             radio/TV        1 2008-04-01 04:29:06        935
# 36         6            education        1 2007-09-27 05:54:11        711
# 37        15  domestic appliances        1 2007-10-23 02:58:49        337
# 38        36                  car        1 2007-05-17 20:02:00         54
# 39        26                  car        0 2007-11-08 13:56:18        525
# 40        42  furniture/equipment        0 2008-02-02 07:35:12          3
# 41        12             radio/TV        1 2008-03-28 10:18:33        188
# 42        36             business        0 2007-07-12 16:29:02        868
# 43        12                  car        1 2007-05-13 15:32:57        835
# 44        30             radio/TV        0 2007-10-08 23:19:47        716
# 45        48             business        1 2007-11-06 02:33:15        622
# 46        30  furniture/equipment        1 2007-11-21 23:06:14        766
# 47        24  furniture/equipment        0 2007-12-24 12:03:24        229
# 48        18             radio/TV        0 2007-05-28 20:16:13        876
# 49        24             radio/TV        0 2007-10-25 09:51:21        683

# %%
df3 = select_conn(query)

# %%
df3
# Out:
#     age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0    43    male    1     own          little             None           1533
# 1    38    male    1     own          little         moderate           1308
# 2    24    male    2     own        moderate         moderate           6560
# 3    30    male    3     own      quite rich             None           2333
# 4    28  female    2     own          little           little           3660
# 5    56    male    2     own          little             None            618
# 6    20  female    2     own            rich         moderate           1577
# 7    37  female    2     own          little         moderate           3612
# 8    31    male    2     own            None             rich           3148
# 9    28    male    2     own          little             None           9572
# 10   32    male    3    free          little             None           4686
# 11   66    male    1     own      quite rich         moderate            766
# 12   31    male    1     own          little         moderate           1928
# 13   63    male    2    free          little             rich            781
# 14   29    male    1     own            None         moderate           2333
# 15   21    male    1    rent          little           little           1987
# 16   35    male    2     own            None             None           1979
# 17   52    male    1     own          little           little           2315
# 18   46    male    3     own            None             None           7629
# 19   53    male    2    free          little           little           4870
# 20   31    male    2     own            None             None            929
# 21   27    male    2     own        moderate         moderate           4576
# 22   46    male    3     own            None             None           6842
# 23   47    male    2    free            None           little           8335
# 24   27    male    0     own            rich             rich            709
# 25   28    male    2     own          little           little           5371
# 26   28    male    2     own        moderate             rich           1323
# 27   51  female    2     own        moderate             None            682
# 28   25    male    2     own            None             None            999
# 29   50  female    1     own          little             rich           1047
# 30   25  female    2    rent            None           little           1371
# 31   34    male    1     own        moderate             None           1743
# 32   23    male    2     own            None         moderate           1444
# 33   34  female    3     own          little         moderate           2064
# 34   34    male    2    free            None             None           6527
# 35   30    male    3     own        moderate         moderate           1919
# 36   35  female    2    free          little           little           1198
# 37   24  female    2    rent            None           little           1275
# 38   57    male    2    free          little         moderate           2225
